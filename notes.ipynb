# %%
## DAY 1 :

# %% [markdown]
# Here's your **Day 01 notebook** — ready to download! 🎉
#
# **What's inside:**
# - `print()`, comments, indentation basics
# - Variables — first look
# - f-strings & string formatting
# - 📝 Quiz (3 questions)
# - 🎤 Interview Questions
# - 🧩 2 Problem Statements
# - 🚀 Use Case: **System Health Dashboard** (using `sys` & `platform`)
#
# **To open it:** Download → open in Jupyter Lab/Notebook or VS Code with the Jupyter extension.
#
# Once you're happy with Day 1's format, just say **"give me Day 2"** (or any day number) and I'll share it instantly — all 40 notebooks are already generated and ready! 📚
