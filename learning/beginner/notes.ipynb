# %% [markdown]
# Here's your **Day 01 notebook** — ready to download! 🎉
#
# **What's inside:**
# - `print()`, comments, indentation basics
# - Variables — first look
# - f-strings & string formatting
# - 📝 Quiz (3 questions)
# - 🎤 Interview Questions
# - 🧩 2 Problem Statements
# - 🚀 Use Case: **System Health Dashboard** (using `sys` & `platform`)

# %% [markdown]
# Here's your **Day 02 notebook** — ready to download! 🎉
#
# **What's inside today:**
#
# | Section | Content |
# |---|---|
# | 📘 Concepts | `int`, `float`, `complex`, `str`, `bool`, `NoneType` |
# | 🔄 Dynamic Typing | How Python lets variables change type |
# | 🔁 Type Conversion | Implicit vs explicit, common pitfalls |
# | 🔍 isinstance() | Why it's better than `type()` for checks |
# | 📝 Quiz | 3 questions with hidden answers |
# | 🎤 Interview Prep | `is` vs `==`, truthy/falsy values |
# | 🧩 Problems | Temp converter + Type Detective table |
# | 🚀 Use Case | **Record Type Validator** — validates data types before DB insert |
